# %% [markdown]
# # **import libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # **read dataset**

# %%
df = pd.read_csv('insurance_dataset.csv')
print(df)
# Out:
#      Age    Insurance
# 0     18   845.220855
# 1     18   855.321953
# 2     18   927.966322
# 3     18   939.023580
# 4     18   963.177166
# ..   ...          ...
# 495   64  2224.291274
# 496   64  2251.291753
# 497   64  2266.606675
# 498   64  2307.016908
# 499   64  2321.476413
#
# [500 rows x 2 columns]

# %% [markdown]
# #**Graph of the Data**

# %%
plt.scatter(df['Age'],df['Insurance'],color='purple')
plt.xlabel('Age')
plt.ylabel('Insurance $')
plt.title('Age vs Insurance')
plt.show()

# %% [markdown]
# #**Preprocessing the Data**

# %%
x = df.iloc[:,0:1]
y = df.iloc[:,1]

# %% [markdown]
# #**Training the Linear Regression Model**

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=3)
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # **MOSHKELA**

# %%
print(lr.predict(x_test.iloc[0].values.reshape(1,1)))
# Out:
# [1396.49626161]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # **Graph of the Trained Model**

# %%
plt.scatter(df['Age'],df['Insurance'],color='purple')
plt.plot(x_train,lr.predict(x_train),color='black')
plt.xlabel('Age')
plt.ylabel('Insurance $')
plt.title('Age vs Insurance')
plt.show()

# %% [markdown]
# # **Calculating the Slope and the Intercept of the Line**

# %%
# y = mx + b [equation of a line]
m = lr.coef_
b = lr.intercept_
print("Slope =",m)
print("Intercept =",b)
# Out:
# Slope = [21.48627994]
# Intercept = 730.4215835741946

# %% [markdown]
# # **Accuracy**

# %%
acc = lr.score(x_test,y_test)
print("Accuracy =",acc*100,"%")
# Out:
# Accuracy = 98.31625471656434 %
